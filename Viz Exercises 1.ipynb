# %% [markdown]
# # Tips

# %% [markdown]
# ### Step 1. Import the necessary libraries:

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset in the PWD

# %%
pd.read_csv("tips.csv")
# Out:
#      Unnamed: 0  total_bill   tip     sex smoker   day    time  size
# 0             0       16.99  1.01  Female     No   Sun  Dinner     2
# 1             1       10.34  1.66    Male     No   Sun  Dinner     3
# 2             2       21.01  3.50    Male     No   Sun  Dinner     3
# 3             3       23.68  3.31    Male     No   Sun  Dinner     2
# 4             4       24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...         ...   ...     ...    ...   ...     ...   ...
# 239         239       29.03  5.92    Male     No   Sat  Dinner     3
# 240         240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241         241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242         242       17.82  1.75    Male     No   Sat  Dinner     2
# 243         243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %% [markdown]
# ### Step 3. Assign it to a variable called tips

# %%
tips = pd.read_csv("tips.csv")

# %% [markdown]
# ### Step 4. Delete the Unnamed 0 column

# %%
del tips['Unnamed: 0']

# %% [markdown]
# ### Step 5. Plot the total_bill column histogram

# %%
sb.set(style="darkgrid")

# %%
x = tips["total_bill"]
sb.distplot(x, kde = True, hist = True, rug= False, bins= 40)
# Out:
# C:\Users\Chetan\anaconda3\anaconda3\New folder\envs\py37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ### Step 6. Create a scatter plot presenting the relationship between total_bill and tip

# %%
sb.jointplot(x = "total_bill",y = "tip",data = tips)

# %% [markdown]
# ### Step 7.  Create one image with the relationship of total_bill, tip and size.
# #### Hint: It is just one function.

# %%
sb.relplot(x = 'total_bill', y = 'tip', style = 'size', data = tips)

# %% [markdown]
# ### Step 8. Present the relationship between days and total_bill value

# %%
sb.catplot(x = 'day', y = 'total_bill', data = tips)

# %%
# Interpretation 
# The total bill paid on saturday is more,compare to Sunday, Thursday and Friday.

# %% [markdown]
# ### Step 9. Create a scatter plot with the day as the y-axis and tip as the x-axis, differ the dots by sex

# %%
sb.relplot(x="tip", y="day", hue="sex", data=tips);

# %% [markdown]
# ### Step 10.  Create a box plot presenting the total_bill per day differetiation the time (Dinner or Lunch)

# %%
sb.catplot(x = 'day', y = 'total_bill', kind = 'box', data = tips, hue = 'time')

# %% [markdown]
# ### Step 11. Create two histograms of the tip value based for Dinner and Lunch. They must be side by side.

# %%
#fig, axes = plt.subplots(1, 2, figsize=(10,5), dpi=100, sharex=True, sharey=True)
#colors = ['tab:red', 'tab:blue']

#for i, (ax, time) in enumerate(zip(axes.flatten(), tips.time.unique())):
#    x = tips.loc[tips.time==time, 'tip']
#    ax.hist(x, alpha=0.5, bins=10, density=True, stacked=True, label=str(time), color=colors[i])
#    ax.set_title(time)

#plt.suptitle('Histogram for tip value based Dinner and Lunch', y=1, size=15)
#ax.set_xlim(0,10 ); ax.set_ylim(0,0.8);

x1 = tips.loc[tips.time=='Lunch', ['tip']]
x2 = tips.loc[tips.time=='Dinner', ['tip']]

# plot
fig, axes = plt.subplots(1, 2, figsize=(10, 5), sharey=True, dpi=100)
sb.distplot(x1 , color="red", ax=axes[0], axlabel='Lunch')
sb.distplot(x2 , color="blue", ax=axes[1], axlabel='Dinner')
plt.xlim(0,10);plt.ylim(0,0.8);
plt.tight_layout();
# Out:
# C:\Users\Chetan\anaconda3\anaconda3\New folder\envs\py37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Chetan\anaconda3\anaconda3\New folder\envs\py37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Step 12. Create two scatterplots graphs, one for Male and another for Female, presenting the total_bill value and tip relationship, differing by smoker or no smoker
# ### They must be side by side.

# %%
sb.lmplot(x = 'total_bill', y = 'tip', data = tips, col = 'sex', col_wrap=2, height = 5,hue = 'smoker',fit_reg = False)
